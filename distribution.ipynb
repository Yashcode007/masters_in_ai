# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashcode007/masters_in_ai/blob/deep_learning_wb_84520/distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lectur 1.3 -> Distribution and Sampling in Pytorch**

# %%
import torch
import torch.distributions as dist

# %%
#Lets create a Bernoulli Distribution

bernoulli = dist.Bernoulli(torch.tensor([0.5]))
print(bernoulli)

#Sample from the distribution
for _ in range(10):
  print(bernoulli.sample())
# Out:
# Bernoulli(probs: tensor([0.5000]))
# tensor([1.])
# tensor([0.])
# tensor([0.])
# tensor([0.])
# tensor([0.])
# tensor([0.])
# tensor([1.])
# tensor([1.])
# tensor([1.])
# tensor([1.])

# %%
samples = [bernoulli.sample() for _ in range(1000)]
print(f"Mean:{torch.mean(torch.stack(samples))}")
print(f"Variance:{torch.var(torch.stack(samples))}")
# Out:
# Mean:0.4880000054836273
# Variance:0.2501060962677002

# %% [markdown]
# We run it multiple time , the mean is sometimes -0.49 , 0.42, 0.52 , etc
#
# But it is rarely 0.5

# %%
# Lets create a normal distribution
# 0.0-> centered at mean , 1.0 -> standard deviation of 1
normal = dist.Normal(torch.tensor([0.0]), torch.tensor([1.0]))

for _ in range(10):
  print(normal.sample())
# Out:
# tensor([1.5304])
# tensor([-1.0506])
# tensor([-0.4628])
# tensor([-0.3418])
# tensor([1.7925])
# tensor([-0.8257])
# tensor([-0.7269])
# tensor([0.5684])
# tensor([-0.4867])
# tensor([0.8032])

# %%
samples = [normal.sample() for _ in range(1000)]
print(f"Mean:{torch.mean(torch.stack(samples))}")
print(f"Variance:{torch.var(torch.stack(samples))}")
# Out:
# Mean:-0.007820331491529942
# Variance:1.0673729181289673
